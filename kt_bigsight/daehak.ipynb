# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
# 4대소비현황/성별소비현황/연령대별소비현황/시간대별소비현황(금액)/시간대별소비현황(비율)/주중주말별소비현황
consume1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='4대소비 현황')
consume2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='성별 소비 현황')
consume3 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='연령대별 소비 현황')
consume4 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='시간대별 소비 현황 (금액)')
consume5 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='시간대별 소비 현황 (비율)')
consume6 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107.xlsx', sheet_name='주중·주말별 소비 현황')

# 내국인관광객현황/성별내국인관광객비교/연령대별내국인관광객비교/...
korean1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='내국인 관광객 현황')
korean2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='성별 내국인 관광객 비교')
korean3 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='연령대별 내국인 관광객 비교')
korean4 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='주중·주말별 내국인 관광객 비교')
korean5 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='주중·주말별 평균 내국인 관광객 비교')
korean6 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='시간대별 내국인 관광객 비교')
korean7 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='외지인 관광객 거주지역 비교')
korean8 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107.xlsx', sheet_name='외지인 관광객 24시간 이후 이동지역 비교')

# %%
consume1['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
consume1 = consume1.sort_values(by=['구분'])
consume1 = consume1.set_index('구분')

consume2['구분'] = ['M','W']
consume2 = consume2.set_index('구분')

consume3['구분'] = ['under20','20s','30s','40s','50s','60s','over70']
consume3 = consume3.set_index('구분')

consume4['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
consume4 = consume4.set_index('구분')

consume5['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
consume5 = consume5.set_index('구분')

sum_consume6_1 = consume6['구분'] == '주중평균'
sum_consume6_2 = consume6['구분'] == '주말평균'
sum_consume6 = sum_consume6_1 | sum_consume6_2
consume6 = consume6[sum_consume6]
consume6['구분'] = ['weekday','weekend']
consume6 = consume6.set_index('구분')

# %%
consume1.loc[['19_08','20_08','20_07','21_07']]
# Out:
#        서울대(행운동)  연세대(신촌동)  고려대(안암동)  ...  외대(이문1동)  시립대(전농2동)  건국대(화양동)
# 구분                                   ...
# 19_08   2403594  17277877   1399002  ...   2069823    1197159  11533007
# 20_08   1910927  11516911   1371141  ...   1696156     928156   8178292
# 20_07   2064028  13651650   1615187  ...   1888590    1041449   9646292
# 21_07   1618749   8292533   1905219  ...   1374774     773392   5284090
#
# [4 rows x 12 columns]

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.subplot(341)
plt.plot(consume1['서울대(행운동)'])
plt.title('Seoul Univ')
plt.subplot(342)
plt.plot(consume1['연세대(신촌동)'])
plt.title('Yonsei Univ')
plt.subplot(343)
plt.plot(consume1['고려대(안암동)'])
plt.title('Korea Univ')
plt.subplot(344)
plt.plot(consume1['홍익대(서교동)'])
plt.title('Hongik Univ')
plt.subplot(345)
plt.plot(consume1['서강대(대흥동)'])
plt.title('Sogang Univ')
plt.subplot(346)
plt.plot(consume1['성대(혜화동)'])
plt.title('Sungkyun Univ')
plt.subplot(347)
plt.plot(consume1['한양대(사근동)'])
plt.title('Hanyang Univ')
plt.subplot(348)
plt.plot(consume1['중앙대(흑석동)'])
plt.title('Chungang Univ')
plt.subplot(349)
plt.plot(consume1['경희대(회기동)'])
plt.title('KyungHee Univ')
plt.subplot(3,4,10)
plt.plot(consume1['외대(이문1동)'])
plt.title('Foreign Univ')
plt.subplot(3,4,11)
plt.plot(consume1['시립대(전농2동)'])
plt.title('Univ of Seoul')
plt.subplot(3,4,12)
plt.plot(consume1['건국대(화양동)'])
plt.title('Konkuk Univ')

plt.show()

# %%
#consume2['서울대(행운동)'].plot(kind='bar')
plt.figure(figsize=(12,12))
plt.subplot(341)
plt.pie(consume2['서울대(행운동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Seoul Univ')
plt.subplot(342)
plt.pie(consume2['연세대(신촌동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Yonsei Univ')
plt.subplot(3,4,3)
plt.pie(consume2['고려대(안암동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Korea Univ')
plt.subplot(3,4,4)
plt.pie(consume2['홍익대(서교동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Hongik Univ')
plt.subplot(345)
plt.pie(consume2['서강대(대흥동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Sogang Univ')
plt.subplot(346)
plt.pie(consume2['성대(혜화동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Sungkyun Univ')
plt.subplot(347)
plt.pie(consume2['한양대(사근동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Hanyang Univ')
plt.subplot(348)
plt.pie(consume2['중앙대(흑석동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Chungang Univ')
plt.subplot(349)
plt.pie(consume2['경희대(회기동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('KyungHee Univ')
plt.subplot(3,4,10)
plt.pie(consume2['외대(이문1동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Foreign Univ')
plt.subplot(3,4,11)
plt.pie(consume2['시립대(전농2동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Univ of Seoul')
plt.subplot(3,4,12)
plt.pie(consume2['건국대(화양동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Konkuk Univ')

plt.show()

# %%
#consume3['서울대(행운동)'].plot(kind='bar')
plt.figure(figsize=(16,16))
plt.subplot(341)
plt.pie(consume3['서울대(행운동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Seoul Univ')
plt.subplot(342)
plt.pie(consume3['연세대(신촌동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Yonsei Univ')
plt.subplot(3,4,3)
plt.pie(consume3['고려대(안암동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Korea Univ')
plt.subplot(3,4,4)
plt.pie(consume3['홍익대(서교동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Hongik Univ')
plt.subplot(345)
plt.pie(consume3['서강대(대흥동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Sogang Univ')
plt.subplot(346)
plt.pie(consume3['성대(혜화동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Sungkyun Univ')
plt.subplot(347)
plt.pie(consume3['한양대(사근동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Hanyang Univ')
plt.subplot(348)
plt.pie(consume3['중앙대(흑석동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Chungang Univ')
plt.subplot(349)
plt.pie(consume3['경희대(회기동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('KyungHee Univ')
plt.subplot(3,4,10)
plt.pie(consume3['외대(이문1동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Foreign Univ')
plt.subplot(3,4,11)
plt.pie(consume3['시립대(전농2동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Univ of Seoul')
plt.subplot(3,4,12)
plt.pie(consume3['건국대(화양동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Konkuk Univ')

plt.show()

# %%
#consume4.plot(kind='bar')
plt.figure(figsize=(16,16))
plt.subplot(341)
plt.pie(consume4['서울대(행운동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Seoul Univ')
plt.subplot(342)
plt.pie(consume4['연세대(신촌동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Yonsei Univ')
plt.subplot(3,4,3)
plt.pie(consume4['고려대(안암동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Korea Univ')
plt.subplot(3,4,4)
plt.pie(consume4['홍익대(서교동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Hongik Univ')
plt.subplot(345)
plt.pie(consume4['서강대(대흥동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Sogang Univ')
plt.subplot(346)
plt.pie(consume4['성대(혜화동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Sungkyun Univ')
plt.subplot(347)
plt.pie(consume4['한양대(사근동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Hanyang Univ')
plt.subplot(348)
plt.pie(consume4['중앙대(흑석동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Chungang Univ')
plt.subplot(349)
plt.pie(consume4['경희대(회기동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('KyungHee Univ')
plt.subplot(3,4,10)
plt.pie(consume4['외대(이문1동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Foreign Univ')
plt.subplot(3,4,11)
plt.pie(consume4['시립대(전농2동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Univ of Seoul')
plt.subplot(3,4,12)
plt.pie(consume4['건국대(화양동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Konkuk Univ')

plt.show()

# %%
#consume5.plot(kind='bar')
#plt.pie(consume5['서울대(행운동)'],labels=consume5.index,autopct='%.1f%%')
#plt.show()
# 4의 pie와 같은 결과임

# %%
consume6
# Out:
#          서울대(행운동)  연세대(신촌동)  고려대(안암동)  ...  외대(이문1동)  시립대(전농2동)  건국대(화양동)
# 구분                                     ...
# weekday   1226932   6419931   1476454  ...   1038690     594850   4029207
# weekend    391817   1872602    428765  ...    336084     178542   1254883
#
# [2 rows x 12 columns]

# %%
#consume6.plot(kind='bar')
plt.figure(figsize=(10,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.5, hspace=0.5)
plt.subplot(441)
plt.bar(consume6.index,consume6['서울대(행운동)'])
plt.title('Seoul Univ')
plt.ylim(0,500000)
plt.subplot(442)
plt.bar(consume6.index,consume6['연세대(신촌동)'])
plt.title('Yonsei Univ')
plt.ylim(0,500000)
plt.subplot(443)
plt.bar(consume6.index,consume6['고려대(안암동)'])
plt.title('Korea Univ')
plt.ylim(0,500000)
plt.subplot(444)
plt.bar(consume6.index,consume6['홍익대(서교동)'])
plt.title('Hongik Univ')
plt.ylim(0,500000)

plt.subplot(4,4,5)
plt.pie(consume6['서울대(행운동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Seoul Univ')
plt.subplot(4,4,6)
plt.pie(consume6['연세대(신촌동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Yonsei Univ')
plt.subplot(4,4,7)
plt.pie(consume6['고려대(안암동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Korea Univ')
plt.subplot(4,4,8)
plt.pie(consume6['홍익대(서교동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Hongik Univ')
plt.subplot(4,4,9)
plt.pie(consume6['서강대(대흥동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Sogang Univ')
plt.subplot(4,4,10)
plt.pie(consume6['성대(혜화동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Sungkyun Univ')
plt.subplot(4,4,11)
plt.pie(consume6['한양대(사근동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Hanyang Univ')
plt.subplot(4,4,12)
plt.pie(consume6['중앙대(흑석동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Chungang Univ')
plt.subplot(4,4,13)
plt.pie(consume6['경희대(회기동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('KyungHee Univ')
plt.subplot(4,4,14)
plt.pie(consume6['외대(이문1동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Foreign Univ')
plt.subplot(4,4,15)
plt.pie(consume6['시립대(전농2동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Univ of Seoul')
plt.subplot(4,4,16)
plt.pie(consume6['건국대(화양동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Konkuk Univ')

plt.show()

# %%
#

# %%
korean1 = korean1.dropna(axis=0)

# %%
korean1_live = korean1[korean1['내국인 구분']=='현지인']
korean1_trip = korean1[korean1['내국인 구분']=='외지인']

korean1_live['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
korean1_live = korean1_live.sort_values(by=['구분'])
korean1_live = korean1_live.set_index('구분')
korean1_live = korean1_live.drop(['내국인 구분'],axis=1)

korean1_trip['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
korean1_trip = korean1_trip.sort_values(by=['구분'])
korean1_trip = korean1_trip.set_index('구분')
korean1_trip = korean1_trip.drop(['내국인 구분'],axis=1)

korean1_sum = korean1_live + korean1_trip

# %%
plt.figure(figsize=(30,8))
plt.plot(korean1_sum['서울대(행운동)'],label='Seoul')
plt.plot(korean1_sum['연세대(신촌동)'],label='Yonsei')
plt.plot(korean1_sum['고려대(안암동)'],label='Korea')
plt.plot(korean1_sum['홍익대(서교동)'],label='Hongik')
plt.plot(korean1_sum['서강대(대흥동)'],label='Sogang')
plt.plot(korean1_sum['성대(혜화동)'],label='Sungkyun')
plt.plot(korean1_sum['한양대(사근동)'],label='Hanyang')
plt.plot(korean1_sum['중앙대(흑석동)'],label='Chungang')
plt.plot(korean1_sum['경희대(회기동)'],label='KyungHee')
plt.plot(korean1_sum['외대(이문1동)'],label='Foreign')
plt.plot(korean1_sum['시립대(전농2동)'],'-.',label='Sirip')
plt.plot(korean1_sum['건국대(화양동)'],'-.',label='Konkuk')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['서울대(행운동)','연세대(신촌동)','고려대(안암동)','홍익대(서교동)','서강대(대흥동)','성대(혜화동)','한양대(사근동)','중앙대(흑석동)','경희대(회기동)','외대(이문1동)','시립대(전농2동)','건국대(화양동)']
e_name = ['Seoul Univ (sum)','Yonsei Univ (sum)','Korea Univ (sum)','Hongik Univ (sum)','Sogang Univ (sum)','Sungkyun Univ (sum)','Hanyang Univ (sum)','Chungang Univ (sum)','KyungHee Univ (sum)','Foreign Univ (sum)','Univ of Seoul (sum)','Konkuk Univ (sum)']
for i in range(12):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_sum[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['서울대(행운동)','연세대(신촌동)','고려대(안암동)','홍익대(서교동)','서강대(대흥동)','성대(혜화동)','한양대(사근동)','중앙대(흑석동)','경희대(회기동)','외대(이문1동)','시립대(전농2동)','건국대(화양동)']
e_name = ['Seoul Univ (live)','Yonsei Univ (live)','Korea Univ (live)','Hongik Univ (live)','Sogang Univ (live)','Sungkyun Univ (live)','Hanyang Univ (live)','Chungang Univ (live)','KyungHee Univ (live)','Foreign Univ (live)','Univ of Seoul (live)','Konkuk Univ (live)']
for i in range(12):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_live[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['서울대(행운동)','연세대(신촌동)','고려대(안암동)','홍익대(서교동)','서강대(대흥동)','성대(혜화동)','한양대(사근동)','중앙대(흑석동)','경희대(회기동)','외대(이문1동)','시립대(전농2동)','건국대(화양동)']
e_name = ['Seoul Univ (trip)','Yonsei Univ (trip)','Korea Univ (trip)','Hongik Univ (trip)','Sogang Univ (trip)','Sungkyun Univ (trip)','Hanyang Univ (trip)','Chungang Univ (trip)','KyungHee Univ (trip)','Foreign Univ (trip)','Univ of Seoul (trip)','Konkuk Univ (trip)']
for i in range(12):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_trip[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
korean2_live = korean2[korean2['내국인 구분']=='현지인']
korean2_trip = korean2[korean2['내국인 구분']=='외지인']

korean2_live['구분'] = ['M','W']
korean2_live = korean2_live.set_index('구분')
korean2_live = korean2_live.drop(['내국인 구분'],axis=1)

korean2_trip['구분'] = ['M','W']
korean2_trip = korean2_trip.set_index('구분')
korean2_trip = korean2_trip.drop(['내국인 구분'],axis=1)

korean2_sum = korean2_live + korean2_trip

# %%
korean2_sum
# Out:
#     서울대(행운동)  연세대(신촌동)  고려대(안암동)  ...  외대(이문1동)  시립대(전농2동)  건국대(화양동)
# 구분                                ...
# M     339189   1489168    411913  ...    364764     321856    768293
# W     346419   1638940    376354  ...    369826     326992    795311
#
# [2 rows x 12 columns]

# %%
plt.figure(figsize=(16,16))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['서울대(행운동)','연세대(신촌동)','고려대(안암동)','홍익대(서교동)','서강대(대흥동)','성대(혜화동)','한양대(사근동)','중앙대(흑석동)','경희대(회기동)','외대(이문1동)','시립대(전농2동)','건국대(화양동)']
e_name_live = ['Seoul Univ (live)','Yonsei Univ (live)','Korea Univ (live)','Hongik Univ (live)','Sogang Univ (live)','Sungkyun Univ (live)','Hanyang Univ (live)','Chungang Univ (live)','KyungHee Univ (live)','Foreign Univ (live)','Univ of Seoul (live)','Konkuk Univ (live)']
e_name_trip = ['Seoul Univ (trip)','Yonsei Univ (trip)','Korea Univ (trip)','Hongik Univ (trip)','Sogang Univ (trip)','Sungkyun Univ (trip)','Hanyang Univ (trip)','Chungang Univ (trip)','KyungHee Univ (trip)','Foreign Univ (trip)','Univ of Seoul (trip)','Konkuk Univ (trip)']
e_name_sum = ['Seoul Univ (sum)','Yonsei Univ (sum)','Korea Univ (sum)','Hongik Univ (sum)','Sogang Univ (sum)','Sungkyun Univ (sum)','Hanyang Univ (sum)','Chungang Univ (sum)','KyungHee Univ (sum)','Foreign Univ (sum)','Univ of Seoul (sum)','Konkuk Univ (sum)']
for i in range(12):
  plt.subplot(6,6,3*i+1)
  plt.pie(korean2_live[k_name[i]],labels=korean2_live.index,autopct='%.1f%%')
  plt.title(e_name_live[i])
  plt.subplot(6,6,3*i+2)
  plt.pie(korean2_trip[k_name[i]],labels=korean2_trip.index,autopct='%.1f%%')
  plt.title(e_name_trip[i])
  plt.subplot(6,6,3*i+3)
  plt.pie(korean2_sum[k_name[i]],labels=korean2_sum.index,autopct='%.1f%%')
  plt.title(e_name_sum[i])
plt.show()

# %%
korean3_live = korean3[korean3['내국인 구분']=='현지인']
korean3_trip = korean3[korean3['내국인 구분']=='외지인']

korean3_live['구분'] = ['under10','10s','20s','30s','40s','50s','60s','over70']
korean3_live = korean3_live.set_index('구분')
korean3_live = korean3_live.drop(['내국인 구분'],axis=1)

korean3_trip['구분'] = ['under10','10s','20s','30s','40s','50s','60s','over70']
korean3_trip = korean3_trip.set_index('구분')
korean3_trip = korean3_trip.drop(['내국인 구분'],axis=1)

korean3_sum = korean3_live + korean3_trip

# %%
korean3_sum
# Out:
#          서울대(행운동)  연세대(신촌동)  고려대(안암동)  ...  외대(이문1동)  시립대(전농2동)  건국대(화양동)
# 구분                                     ...
# under10      3710      4626      1823  ...      3028       7442      3230
# 10s         28540    120220     47093  ...     49645      50632     82808
# 20s        224928   1191917    315451  ...    311212     131806    705353
# 30s        139802    572250    109921  ...     92756     104437    267292
# 40s         85173    383435     78175  ...     81516     105407    160185
# 50s         86073    422424     99185  ...     83626     109660    159476
# 60s         68707    302277     82650  ...     70906      89818    125797
# over70      48676    130959     53969  ...     41903      49645     59461
#
# [8 rows x 12 columns]

# %%
plt.figure(figsize=(16,16))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.subplot(341)
plt.pie(korean3_sum['서울대(행운동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Seoul Univ (sum)')
plt.subplot(342)
plt.pie(korean3_sum['연세대(신촌동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Yonsei Univ (sum)')
plt.subplot(343)
plt.pie(korean3_sum['고려대(안암동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Korea Univ (sum)')
plt.subplot(344)
plt.pie(korean3_sum['홍익대(서교동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Hongik Univ (sum)')
plt.subplot(3,4,5)
plt.pie(korean3_sum['서강대(대흥동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Sogang Univ (sum)')
plt.subplot(3,4,6)
plt.pie(korean3_sum['성대(혜화동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Sungkyun Univ (sum)')
plt.subplot(3,4,7)
plt.pie(korean3_sum['한양대(사근동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Hanyang Univ (sum)')
plt.subplot(3,4,8)
plt.pie(korean3_sum['중앙대(흑석동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Chungang Univ (sum)')
plt.subplot(3,4,9)
plt.pie(korean3_sum['경희대(회기동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('KyungHee Univ (sum)')
plt.subplot(3,4,10)
plt.pie(korean3_sum['외대(이문1동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Foreign Univ (sum)')
plt.subplot(3,4,11)
plt.pie(korean3_sum['시립대(전농2동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Univ of Seoul (sum)')
plt.subplot(3,4,12)
plt.pie(korean3_sum['건국대(화양동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Konkuk Univ (sum)')

plt.show()

# %%
# korean4

# %%
korean5_live = korean5[korean5['내국인 구분']=='현지인']
korean5_trip = korean5[korean5['내국인 구분']=='외지인']

korean5_live['구분'] = ['weekday','weekend']
korean5_live = korean5_live.set_index('구분')
korean5_live = korean5_live.drop(['내국인 구분'],axis=1)

korean5_trip['구분'] = ['weekday','weekend']
korean5_trip = korean5_trip.set_index('구분')
korean5_trip = korean5_trip.drop(['내국인 구분'],axis=1)

korean5_sum = korean5_live + korean5_trip

# %%
plt.figure(figsize=(12,12))
plt.subplot(341)
plt.pie(korean5_sum['서울대(행운동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Seoul Univ (sum)')
plt.subplot(342)
plt.pie(korean5_sum['연세대(신촌동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Yonsei Univ (sum)')
plt.subplot(343)
plt.pie(korean5_sum['고려대(안암동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Korea Univ (sum)')
plt.subplot(344)
plt.pie(korean5_sum['홍익대(서교동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Hongik Univ (sum)')
plt.subplot(3,4,5)
plt.pie(korean5_sum['서강대(대흥동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Sogang Univ (sum)')
plt.subplot(3,4,6)
plt.pie(korean5_sum['성대(혜화동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Sungkyun Univ (sum)')
plt.subplot(3,4,7)
plt.pie(korean5_sum['한양대(사근동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Hanyang Univ (sum)')
plt.subplot(3,4,8)
plt.pie(korean5_sum['중앙대(흑석동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Chungang Univ (sum)')
plt.subplot(3,4,9)
plt.pie(korean5_sum['경희대(회기동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('KyungHee Univ (sum)')
plt.subplot(3,4,10)
plt.pie(korean5_sum['외대(이문1동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Foreign Univ (sum)')
plt.subplot(3,4,11)
plt.pie(korean5_sum['시립대(전농2동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Univ of Seoul (sum)')
plt.subplot(3,4,12)
plt.pie(korean5_sum['건국대(화양동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Konkuk Univ (sum)')

plt.show()

# %%
korean6_live = korean6[korean6['내국인 구분']=='현지인']
korean6_trip = korean6[korean6['내국인 구분']=='외지인']

korean6_live['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
korean6_live = korean6_live.set_index('구분')
korean6_live = korean6_live.drop(['내국인 구분'],axis=1)

korean6_trip['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
korean6_trip = korean6_trip.set_index('구분')
korean6_trip = korean6_trip.drop(['내국인 구분'],axis=1)

korean6_sum = korean6_live + korean6_trip

# %%
plt.figure(figsize=(20,20))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['서울대(행운동)','연세대(신촌동)','고려대(안암동)','홍익대(서교동)','서강대(대흥동)','성대(혜화동)','한양대(사근동)','중앙대(흑석동)','경희대(회기동)','외대(이문1동)','시립대(전농2동)','건국대(화양동)']
e_name_live = ['Seoul Univ (live)','Yonsei Univ (live)','Korea Univ (live)','Hongik Univ (live)','Sogang Univ (live)','Sungkyun Univ (live)','Hanyang Univ (live)','Chungang Univ (live)','KyungHee Univ (live)','Foreign Univ (live)','Univ of Seoul (live)','Konkuk Univ (live)']
e_name_trip = ['Seoul Univ (trip)','Yonsei Univ (trip)','Korea Univ (trip)','Hongik Univ (trip)','Sogang Univ (trip)','Sungkyun Univ (trip)','Hanyang Univ (trip)','Chungang Univ (trip)','KyungHee Univ (trip)','Foreign Univ (trip)','Univ of Seoul (trip)','Konkuk Univ (trip)']
e_name_sum = ['Seoul Univ (sum)','Yonsei Univ (sum)','Korea Univ (sum)','Hongik Univ (sum)','Sogang Univ (sum)','Sungkyun Univ (sum)','Hanyang Univ (sum)','Chungang Univ (sum)','KyungHee Univ (sum)','Foreign Univ (sum)','Univ of Seoul (sum)','Konkuk Univ (sum)']
for i in range(12):
  plt.subplot(6,6,3*i+1)
  plt.pie(korean6_live[k_name[i]],labels=korean6_live.index,autopct='%.1f%%')
  plt.title(e_name_live[i])
  plt.subplot(6,6,3*i+2)
  plt.pie(korean6_trip[k_name[i]],labels=korean6_trip.index,autopct='%.1f%%')
  plt.title(e_name_trip[i])
  plt.subplot(6,6,3*i+3)
  plt.pie(korean6_sum[k_name[i]],labels=korean6_sum.index,autopct='%.1f%%')
  plt.title(e_name_sum[i])
plt.show()

# %%
# korean7, 8은 보고서 참고
