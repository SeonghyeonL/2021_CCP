# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
# 4대소비현황/성별소비현황/연령대별소비현황/시간대별소비현황(금액)/시간대별소비현황(비율)/주중주말별소비현황
consume1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='4대소비 현황')
consume2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='성별 소비 현황')
consume3 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='연령대별 소비 현황')
consume4 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='시간대별 소비 현황 (금액)')
consume5 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='시간대별 소비 현황 (비율)')
consume6 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/consume_202107_w.xlsx', sheet_name='주중·주말별 소비 현황')

# 내국인관광객현황/성별내국인관광객비교/연령대별내국인관광객비교/...
korean1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='내국인 관광객 현황')
korean2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='성별 내국인 관광객 비교')
korean3 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='연령대별 내국인 관광객 비교')
korean4 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='주중·주말별 내국인 관광객 비교')
korean5 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='주중·주말별 평균 내국인 관광객 비교')
korean6 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='시간대별 내국인 관광객 비교')
korean7 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='외지인 관광객 거주지역 비교')
korean8 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2021CCP/univ_area/korean_202107_w.xlsx', sheet_name='외지인 관광객 24시간 이후 이동지역 비교')

# %%
consume1['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
consume1 = consume1.sort_values(by=['구분'])
consume1 = consume1.set_index('구분')

consume2['구분'] = ['M','W']
consume2 = consume2.set_index('구분')

consume3['구분'] = ['under20','20s','30s','40s','50s','60s','over70']
consume3 = consume3.set_index('구분')

consume4['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
consume4 = consume4.set_index('구분')

consume5['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
consume5 = consume5.set_index('구분')

sum_consume6_1 = consume6['구분'] == '주중평균'
sum_consume6_2 = consume6['구분'] == '주말평균'
sum_consume6 = sum_consume6_1 | sum_consume6_2
consume6 = consume6[sum_consume6]
consume6['구분'] = ['weekday','weekend']
consume6 = consume6.set_index('구분')

# %%
consume1.loc[['19_08','20_08','20_07','21_07']]
# Out:
#        숙명여(청파동)  성신여(동선동)  동덕여(월곡2동)  서울여(공릉2동)
# 구분
# 19_08   3674072   5931765    1888693    3394537
# 20_08   3588917   4563580    1540783    2942029
# 20_07   4167806   5084991    1787065    3328200
# 21_07   3883308   3430444    1315799    2784360

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.subplot(341)
plt.plot(consume1['숙명여(청파동)'])
plt.title('Sookmyung')
plt.subplot(342)
plt.plot(consume1['성신여(동선동)'])
plt.title('Sungshin')
plt.subplot(343)
plt.plot(consume1['동덕여(월곡2동)'])
plt.title('Dongduk')
plt.subplot(344)
plt.plot(consume1['서울여(공릉2동)'])
plt.title('Seoul.W')

plt.show()

# %%
plt.figure(figsize=(12,12))
plt.subplot(341)
plt.pie(consume2['숙명여(청파동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Sookmyung')
plt.subplot(342)
plt.pie(consume2['성신여(동선동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Sungshin')
plt.subplot(3,4,3)
plt.pie(consume2['동덕여(월곡2동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Dongduk')
plt.subplot(3,4,4)
plt.pie(consume2['서울여(공릉2동)'],labels=consume2.index,autopct='%.2f%%')
plt.title('Seoul.W')

plt.show()

# %%
plt.figure(figsize=(16,16))
plt.subplot(341)
plt.pie(consume3['숙명여(청파동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Sookmyung')
plt.subplot(342)
plt.pie(consume3['성신여(동선동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Sungshin')
plt.subplot(3,4,3)
plt.pie(consume3['동덕여(월곡2동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Dongduk')
plt.subplot(3,4,4)
plt.pie(consume3['서울여(공릉2동)'],labels=consume3.index,autopct='%.2f%%')
plt.title('Seoul.W')

plt.show()

# %%
plt.figure(figsize=(16,16))
plt.subplot(341)
plt.pie(consume4['숙명여(청파동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Sookmyung')
plt.subplot(342)
plt.pie(consume4['성신여(동선동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Sungshin')
plt.subplot(3,4,3)
plt.pie(consume4['동덕여(월곡2동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Dongduk')
plt.subplot(3,4,4)
plt.pie(consume4['서울여(공릉2동)'],labels=consume4.index,autopct='%.2f%%')
plt.title('Seoul.W')

plt.show()

# %%
#consume5.plot(kind='bar')
# 4의 pie와 같은 결과임

# %%
consume6
# Out:
#          숙명여(청파동)  성신여(동선동)  동덕여(월곡2동)  서울여(공릉2동)
# 구분
# weekday    140589    118688      46208      97054
# weekend     87816     91033      33246      72131

# %%
#consume6.plot(kind='bar')
plt.figure(figsize=(10,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.5, hspace=0.5)
plt.subplot(441)
plt.bar(consume6.index,consume6['숙명여(청파동)'])
plt.title('Sookmyung')
plt.ylim(0,500000)
plt.subplot(442)
plt.bar(consume6.index,consume6['성신여(동선동)'])
plt.title('Sungshin')
plt.ylim(0,500000)
plt.subplot(443)
plt.bar(consume6.index,consume6['동덕여(월곡2동)'])
plt.title('Dongduk')
plt.ylim(0,500000)
plt.subplot(444)
plt.bar(consume6.index,consume6['서울여(공릉2동)'])
plt.title('Seoul.W')
plt.ylim(0,500000)

plt.subplot(4,4,5)
plt.pie(consume6['숙명여(청파동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Sookmyung')
plt.subplot(4,4,6)
plt.pie(consume6['성신여(동선동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Sungshin')
plt.subplot(4,4,7)
plt.pie(consume6['동덕여(월곡2동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Dongduk')
plt.subplot(4,4,8)
plt.pie(consume6['서울여(공릉2동)'],labels=consume6.index,autopct='%.2f%%')
plt.title('Seoul.W')

plt.show()

# %%
#

# %%
korean1 = korean1.dropna(axis=0)

# %%
korean1_live = korean1[korean1['내국인 구분']=='현지인']
korean1_trip = korean1[korean1['내국인 구분']=='외지인']

korean1_live['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
korean1_live = korean1_live.sort_values(by=['구분'])
korean1_live = korean1_live.set_index('구분')
korean1_live = korean1_live.drop(['내국인 구분'],axis=1)

korean1_trip['구분'] = ['21_07','21_06','21_05','21_04','21_03','21_02','21_01','20_12','20_11','20_10','20_09','20_08','20_07','20_06','20_05','20_04','20_03','20_02','20_01','19_12','19_11','19_10','19_09','19_08']
korean1_trip = korean1_trip.sort_values(by=['구분'])
korean1_trip = korean1_trip.set_index('구분')
korean1_trip = korean1_trip.drop(['내국인 구분'],axis=1)

korean1_sum = korean1_live + korean1_trip

# %%
plt.figure(figsize=(30,8))
plt.plot(korean1_sum['숙명여(청파동)'],label='Sookmyung')
plt.plot(korean1_sum['성신여(동선동)'],label='Sungshin')
plt.plot(korean1_sum['동덕여(월곡2동)'],label='Dongduk')
plt.plot(korean1_sum['서울여(공릉2동)'],label='Seoul.W')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['숙명여(청파동)','성신여(동선동)','동덕여(월곡2동)','서울여(공릉2동)']
e_name = ['Sookmyung (sum)','Sungshin (sum)','Dongduk (sum)','Seoul.W (sum)']
for i in range(4):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_sum[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['숙명여(청파동)','성신여(동선동)','동덕여(월곡2동)','서울여(공릉2동)']
e_name = ['Sookmyung (live)','Sungshin (live)','Dongduk (live)','Seoul.W (live)']
for i in range(4):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_live[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
plt.figure(figsize=(30,8))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['숙명여(청파동)','성신여(동선동)','동덕여(월곡2동)','서울여(공릉2동)']
e_name = ['Sookmyung (trip)','Sungshin (trip)','Dongduk (trip)','Seoul.W (trip)']
for i in range(4):
  plt.subplot(3,4,i+1)
  plt.plot(korean1_trip[k_name[i]])
  plt.title(e_name[i])
plt.show()

# %%
korean2_live = korean2[korean2['내국인 구분']=='현지인']
korean2_trip = korean2[korean2['내국인 구분']=='외지인']

korean2_live['구분'] = ['M','W']
korean2_live = korean2_live.set_index('구분')
korean2_live = korean2_live.drop(['내국인 구분'],axis=1)

korean2_trip['구분'] = ['M','W']
korean2_trip = korean2_trip.set_index('구분')
korean2_trip = korean2_trip.drop(['내국인 구분'],axis=1)

korean2_sum = korean2_live + korean2_trip

# %%
korean2_sum
# Out:
#     숙명여(청파동)  성신여(동선동)  동덕여(월곡2동)  서울여(공릉2동)
# 구분
# M     506766    587884     465850     650663
# W     490157    674884     426626     576577

# %%
plt.figure(figsize=(16,16))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.1, hspace=0.2)
k_name = ['숙명여(청파동)','성신여(동선동)','동덕여(월곡2동)','서울여(공릉2동)']
e_name_live = ['Sookmyung (live)','Sungshin (live)','Dongduk (live)','Seoul.W (live)']
e_name_trip = ['Sookmyung (trip)','Sungshin (trip)','Dongduk (trip)','Seoul.W (trip)']
e_name_sum = ['Sookmyung (sum)','Sungshin (sum)','Dongduk (sum)','Seoul.W (sum)']
for i in range(4):
  plt.subplot(6,6,3*i+1)
  plt.pie(korean2_live[k_name[i]],labels=korean2_live.index,autopct='%.1f%%')
  plt.title(e_name_live[i])
  plt.subplot(6,6,3*i+2)
  plt.pie(korean2_trip[k_name[i]],labels=korean2_trip.index,autopct='%.1f%%')
  plt.title(e_name_trip[i])
  plt.subplot(6,6,3*i+3)
  plt.pie(korean2_sum[k_name[i]],labels=korean2_sum.index,autopct='%.1f%%')
  plt.title(e_name_sum[i])
plt.show()

# %%
korean3_live = korean3[korean3['내국인 구분']=='현지인']
korean3_trip = korean3[korean3['내국인 구분']=='외지인']

korean3_live['구분'] = ['under10','10s','20s','30s','40s','50s','60s','over70']
korean3_live = korean3_live.set_index('구분')
korean3_live = korean3_live.drop(['내국인 구분'],axis=1)

korean3_trip['구분'] = ['under10','10s','20s','30s','40s','50s','60s','over70']
korean3_trip = korean3_trip.set_index('구분')
korean3_trip = korean3_trip.drop(['내국인 구분'],axis=1)

korean3_sum = korean3_live + korean3_trip

# %%
korean3_sum
# Out:
#          숙명여(청파동)  성신여(동선동)  동덕여(월곡2동)  서울여(공릉2동)
# 구분
# under10      3456      7631       6395      10173
# 10s         51158    114781      53528     105219
# 20s        277007    395187     176702     287976
# 30s        199179    210187     151163     184197
# 40s        151891    181369     149302     190281
# 50s        159317    177577     166287     219418
# 60s        106857    117353     128250     163047
# over70      48059     58685      60849      66928

# %%
plt.figure(figsize=(16,16))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.subplot(341)
plt.pie(korean3_sum['숙명여(청파동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Sookmyung (sum)')
plt.subplot(342)
plt.pie(korean3_sum['성신여(동선동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Sungshin (sum)')
plt.subplot(343)
plt.pie(korean3_sum['동덕여(월곡2동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Dongduk (sum)')
plt.subplot(344)
plt.pie(korean3_sum['서울여(공릉2동)'],labels=korean3_sum.index,autopct='%.1f%%')
plt.title('Seoul.W (sum)')

plt.show()

# %%
# korean4

# %%
korean5_live = korean5[korean5['내국인 구분']=='현지인']
korean5_trip = korean5[korean5['내국인 구분']=='외지인']

korean5_live['구분'] = ['weekday','weekend']
korean5_live = korean5_live.set_index('구분')
korean5_live = korean5_live.drop(['내국인 구분'],axis=1)

korean5_trip['구분'] = ['weekday','weekend']
korean5_trip = korean5_trip.set_index('구분')
korean5_trip = korean5_trip.drop(['내국인 구분'],axis=1)

korean5_sum = korean5_live + korean5_trip

# %%
plt.figure(figsize=(12,12))
plt.subplot(341)
plt.pie(korean5_sum['숙명여(청파동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Sookmyung (sum)')
plt.subplot(342)
plt.pie(korean5_sum['성신여(동선동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Sungshin (sum)')
plt.subplot(343)
plt.pie(korean5_sum['동덕여(월곡2동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Dongduk (sum)')
plt.subplot(344)
plt.pie(korean5_sum['서울여(공릉2동)'],labels=korean5_sum.index,autopct='%.1f%%')
plt.title('Seoul.W (sum)')

plt.show()

# %%
korean6_live = korean6[korean6['내국인 구분']=='현지인']
korean6_trip = korean6[korean6['내국인 구분']=='외지인']

korean6_live['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
korean6_live = korean6_live.set_index('구분')
korean6_live = korean6_live.drop(['내국인 구분'],axis=1)

korean6_trip['구분'] = ['00_06','06_11','11_14','14_18','18_21','21_24']
korean6_trip = korean6_trip.set_index('구분')
korean6_trip = korean6_trip.drop(['내국인 구분'],axis=1)

korean6_sum = korean6_live + korean6_trip

# %%
plt.figure(figsize=(20,20))
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
k_name = ['숙명여(청파동)','성신여(동선동)','동덕여(월곡2동)','서울여(공릉2동)']
e_name_live = ['Sookmyung (live)','Sungshin (live)','Dongduk (live)','Seoul.W (live)']
e_name_trip = ['Sookmyung (trip)','Sungshin (trip)','Dongduk (trip)','Seoul.W (trip)']
e_name_sum = ['Sookmyung (sum)','Sungshin (sum)','Dongduk (sum)','Seoul.W (sum)']
for i in range(4):
  plt.subplot(6,6,3*i+1)
  plt.pie(korean6_live[k_name[i]],labels=korean6_live.index,autopct='%.1f%%')
  plt.title(e_name_live[i])
  plt.subplot(6,6,3*i+2)
  plt.pie(korean6_trip[k_name[i]],labels=korean6_trip.index,autopct='%.1f%%')
  plt.title(e_name_trip[i])
  plt.subplot(6,6,3*i+3)
  plt.pie(korean6_sum[k_name[i]],labels=korean6_sum.index,autopct='%.1f%%')
  plt.title(e_name_sum[i])
plt.show()

# %%
# korean7, 8은 보고서 참고
